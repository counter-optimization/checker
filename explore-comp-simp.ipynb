# %%
import pandas

# %%
data = pandas.read_csv("Hacl_Curve25519_51_O0.o-Hacl_Impl_Curve25519_Field51_fmul2.csv")
data
# Out:
#        address                      expression  operation  bitwidth  \
# 0     0x404010   Sub64(t93,0x0000000000000008)  Iop_Sub64        64
# 1     0x404014                    Sub64(t4,t3)  Iop_Sub64        64
# 2     0x40401b   Add64(t96,0xfffffffffffffff8)  Iop_Add64        64
# 3     0x40401f   Add64(t99,0xfffffffffffffff0)  Iop_Add64        64
# 4     0x404023  Add64(t102,0xffffffffffffffe8)  Iop_Add64        64
# ...        ...                             ...        ...       ...
# 2262  0x4074b3   Add64(t42,0x0000000000000048)  Iop_Add64        64
# 2263  0x4074b7                  Add64(t11,t10)  Iop_Add64        64
# 2264  0x4074be   Add64(t13,0x0000000000000008)  Iop_Add64        64
# 2265  0x4074bf   Add64(t14,0x0000000000000008)  Iop_Add64        64
# 2266  0x4074bf   Sub64(t16,0x0000000000000080)  Iop_Sub64        64
#
#       numConstantOperands         firstOperandConst  \
# 0                       2  <BV64 0x7fffffffffefdf8>
# 1                       2  <BV64 0x7fffffffffefdf0>
# 2                       2  <BV64 0x7fffffffffefdf0>
# 3                       2  <BV64 0x7fffffffffefdf0>
# 4                       2  <BV64 0x7fffffffffefdf0>
# ...                   ...                       ...
# 2262                    2  <BV64 0x7fffffffffefe00>
# 2263                    2  <BV64 0x7fffffffffee3a0>
# 2264                    2  <BV64 0x7fffffffffefdf0>
# 2265                    2  <BV64 0x7fffffffffefdf8>
# 2266                    2  <BV64 0x7fffffffffefe00>
#
#              secondOperandConst  numPowerOfTwoOperands  \
# 0                    <BV64 0x8>                      0
# 1                 <BV64 0x1a50>                      0
# 2     <BV64 0xfffffffffffffff8>                      0
# 3     <BV64 0xfffffffffffffff0>                      0
# 4     <BV64 0xffffffffffffffe8>                      0
# ...                         ...                    ...
# 2262                <BV64 0x48>                      0
# 2263              <BV64 0x1a50>                      0
# 2264                 <BV64 0x8>                      0
# 2265                 <BV64 0x8>                      0
# 2266                <BV64 0x80>                      0
#
#       firstOperandPowerOfTwo  secondOperandPowerOfTwo  numIdentityOperands  \
# 0                      False                    False                    0
# 1                      False                    False                    0
# 2                      False                    False                    0
# 3                      False                    False                    0
# 4                      False                    False                    0
# ...                      ...                      ...                  ...
# 2262                   False                    False                    0
# 2263                   False                    False                    0
# 2264                   False                    False                    0
# 2265                   False                    False                    0
# 2266                   False                    False                    0
#
#       firstOperandIdentity  secondOperandIdentity  numZeroElementOperands  \
# 0                    False                  False                       0
# 1                    False                  False                       0
# 2                    False                  False                       0
# 3                    False                  False                       0
# 4                    False                  False                       0
# ...                    ...                    ...                     ...
# 2262                 False                  False                       0
# 2263                 False                  False                       0
# 2264                 False                  False                       0
# 2265                 False                  False                       0
# 2266                 False                  False                       0
#
#       firstOperandZeroElem  secondOperandZeroElem
# 0                    False                  False
# 1                    False                  False
# 2                    False                  False
# 3                    False                  False
# 4                    False                  False
# ...                    ...                    ...
# 2262                 False                  False
# 2263                 False                  False
# 2264                 False                  False
# 2265                 False                  False
# 2266                 False                  False
#
# [2267 rows x 16 columns]

# %%
# Shape of the data
print("Shape: %s" % data.shape)
# Out:
# (2267, 16)

# %%
# How many insns are not simplifiable
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2267 entries, 0 to 2266
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   address                  2267 non-null   object
#  1   expression               2267 non-null   object
#  2   operation                2267 non-null   object
#  3   bitwidth                 2267 non-null   int64
#  4   numConstantOperands      2267 non-null   int64
#  5   firstOperandConst        2267 non-null   object
#  6   secondOperandConst       2267 non-null   object
#  7   numPowerOfTwoOperands    2267 non-null   int64
#  8   firstOperandPowerOfTwo   2267 non-null   bool
#  9   secondOperandPowerOfTwo  2267 non-null   bool
#  10  numIdentityOperands      2267 non-null   int64
#  11  firstOperandIdentity     2267 non-null   bool
#  12  secondOperandIdentity    2267 non-null   bool
#  13  numZeroElementOperands   2267 non-null   int64
#  14  firstOperandZeroElem     2267 non-null   bool
#  15  secondOperandZeroElem    2267 non-null   bool
# dtypes: bool(6), int64(5), object(5)
# memory usage: 190.5+ KB
